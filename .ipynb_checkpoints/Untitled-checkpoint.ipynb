# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from tqdm.notebook import tqdm
from sklearn.linear_model import LogisticRegression
# %matplotlib inline
plt.style.use('ggplot')

# %%
#Initial cleanup
df = pd.read_csv("watch_data.csv")
df.drop("Line", axis = 1, inplace= True)
df.dropna(inplace = True)
df["Timestamp"] = pd.to_datetime(df.Date + ' ' + df.Time)
df
# Out:
#             Date        Time  Off-Wrist Status  Activity  Marker  White Light  \
# 8      3/30/2016  3:02:00 PM                 0     298.0     0.0      1458.34
# 9      3/30/2016  3:02:15 PM                 0     215.0     0.0      2246.85
# 10     3/30/2016  3:02:30 PM                 0     245.0     0.0      1655.96
# 11     3/30/2016  3:02:45 PM                 0     215.0     0.0      1194.22
# 12     3/30/2016  3:03:00 PM                 0     208.0     0.0      1486.55
# ...          ...         ...               ...       ...     ...          ...
# 86386  4/14/2016  2:56:30 PM                 0       0.0     0.0         0.00
# 86387  4/14/2016  2:56:45 PM                 0       0.0     0.0         0.00
# 86388  4/14/2016  2:57:00 PM                 0       0.0     0.0         0.00
# 86389  4/14/2016  2:57:15 PM                 0       0.0     0.0         0.00
# 86390  4/14/2016  2:57:30 PM                 0       0.0     0.0         0.00
#
#        Red Light  Green Light  Blue Light  Sleep/Wake Interval Status  \
# 8         1630.0       1620.0       502.0         1.0          ACTIVE
# 9         2720.0       2300.0       817.0         1.0          ACTIVE
# 10        2410.0       1590.0       822.0         1.0          ACTIVE
# 11        2520.0       1020.0       447.0         1.0          ACTIVE
# 12        2720.0       1320.0       618.0         1.0          ACTIVE
# ...          ...          ...         ...         ...             ...
# 86386        0.0          0.0         0.0         0.0          ACTIVE
# 86387        0.0          0.0         0.0         0.0          ACTIVE
# 86388        0.0          0.0         0.0         0.0          ACTIVE
# 86389        0.0          0.0         0.0         0.0          ACTIVE
# 86390        0.0          0.0         0.0         0.0          ACTIVE
#
#                 Timestamp
# 8     2016-03-30 15:02:00
# 9     2016-03-30 15:02:15
# 10    2016-03-30 15:02:30
# 11    2016-03-30 15:02:45
# 12    2016-03-30 15:03:00
# ...                   ...
# 86386 2016-04-14 14:56:30
# 86387 2016-04-14 14:56:45
# 86388 2016-04-14 14:57:00
# 86389 2016-04-14 14:57:15
# 86390 2016-04-14 14:57:30
#
# [85779 rows x 12 columns]

# %%
log_reg = LogisticRegression()
X = df.Activity.to_numpy().reshape(-1,1)
y = df["Sleep/Wake"]
log_reg.fit(X,y)
# Out:
# LogisticRegression()

# %%
df["act_log"] = log_reg.predict_proba(X)
df.head()
# Out:
#          Date        Time  Off-Wrist Status  Activity  Marker  White Light  \
# 8   3/30/2016  3:02:00 PM                 0     298.0     0.0      1458.34
# 9   3/30/2016  3:02:15 PM                 0     215.0     0.0      2246.85
# 10  3/30/2016  3:02:30 PM                 0     245.0     0.0      1655.96
# 11  3/30/2016  3:02:45 PM                 0     215.0     0.0      1194.22
# 12  3/30/2016  3:03:00 PM                 0     208.0     0.0      1486.55
#
#     Red Light  Green Light  Blue Light  Sleep/Wake Interval Status  \
# 8      1630.0       1620.0       502.0         1.0          ACTIVE
# 9      2720.0       2300.0       817.0         1.0          ACTIVE
# 10     2410.0       1590.0       822.0         1.0          ACTIVE
# 11     2520.0       1020.0       447.0         1.0          ACTIVE
# 12     2720.0       1320.0       618.0         1.0          ACTIVE
#
#              Timestamp  act_log
# 8  2016-03-30 15:02:00      0.0
# 9  2016-03-30 15:02:15      0.0
# 10 2016-03-30 15:02:30      0.0
# 11 2016-03-30 15:02:45      0.0
# 12 2016-03-30 15:03:00      0.0

# %%
df["Date"] = df.Timestamp.transform(func = lambda x : x.day_of_year)
df['Time'] = df.Timestamp.transform(func = lambda x : x.hour + x.minute/60 + x.second/3600)

# %%
m = df.Activity.mean()
std = df.Activity.std()
df["act_norm"] = df.Activity.transform(func = lambda x: (x-m)/std)

# %%
plt.figure(figsize=(12.5,7.5))
plt.scatter(dfs + df.act_norm, df.Date)

# %%
plt.scatter(df.Activity, df["Sleep/Wake"])
